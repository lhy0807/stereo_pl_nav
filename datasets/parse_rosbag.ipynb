# %% [markdown]
# # Install Dependency

# %%
# !pip install open3d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
left_img = np.load("sample_left.npy")

# %%
plt.imshow(left_img)

# %%
right_img = np.load("sample_right.npy")

# %%
plt.imshow(right_img)

# %%
pc = np.load("sample_pc.npy")

# %%
gt_pcd = o3d.geometry.PointCloud()
gt_pcd.points = o3d.utility.Vector3dVector(pc)

# %%
o3d.visualization.draw_geometries([gt_pcd], 
                                  lookat=[ -7.9828657243072856, -1.7309350371846659, 8.1875973937279909 ],
                                  up=[ -0.01884077792038092, -0.99848447602495649, 0.051708570126460816 ],
                                  front=[ 0.69436612901506267, -0.050278282769474117, -0.71786333877583575 ],
                                  zoom=0.16)
